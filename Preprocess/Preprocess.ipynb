# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/RechargeGW.xlsx',sheet_name='Working data')

# %%
df.head(100)
# Out:
#                                   DBV    DISTRICT          BLOCK  \
# 0   BATHINDA | TALWANDI SABO | JAJJAL    BATHINDA  TALWANDI SABO
# 1         BATHINDA | BATHINDA | TEONA    BATHINDA       BATHINDA
# 2     BATHINDA | SANGAT | RAIKE KALAN    BATHINDA         SANGAT
# 3   BATHINDA | NATHANA | KALYAN SUKHA    BATHINDA        NATHANA
# 4     BATHINDA | NATHANA | LEHRA BEGA    BATHINDA        NATHANA
# ..                                ...         ...            ...
# 95    PATHANKOT | PATHANKOT | MIRTHAL   PATHANKOT      PATHANKOT
# 96       SANGRUR | SANGRUR | LONGOWAL     SANGRUR        SANGRUR
# 97    AMRITSAR | RAYYA | WADALA KALAN    AMRITSAR          RAYYA
# 98       HOSHIARPUR | BHUNGA | BHUNGA  HOSHIARPUR         BHUNGA
# 99       HOSHIARPUR | DASUYA | SUSPUR  HOSHIARPUR         DASUYA
#
#          VILLAGE  1986  1987  1988  1989  1990  1991  ...  2010  2011  2012  \
# 0         JAJJAL  0.03 -0.84 -2.61 -0.21 -0.60 -0.20  ... -0.31 -0.45 -1.32
# ...

# %%
df.columns
# Out:
# Index([     'DBV', 'DISTRICT',    'BLOCK',  'VILLAGE', 'LONG_DEG', 'LONG_MIN',
#        'LONG_SEC', 'LATI_DEG', 'LATI_MIN', 'LATI_SEC',       1986,       1987,
#              1988,       1989,       1990,       1991,       1992,       1993,
#              1994,       1995,       1996,       1997,       1998,       1999,
#              2000,       2001,       2002,       2003,       2004,       2005,
#              2006,       2007,       2008,       2009,       2010,       2011,
#              2012,       2013,       2014,       2015,       2016,       2017,
#              2018,       2019,     'NULL',      'SUM', 'NOT NULL',  'Average',
#             'STD'],
#       dtype='object')

# %%
df.drop(['LONG_DEG', 'LONG_MIN',
       'LONG_SEC', 'LATI_DEG', 'LATI_MIN', 'LATI_SEC','NULL',      'SUM', 'NOT NULL',  'Average',
            'STD'],axis=1,inplace=True)

# %%
df.replace(0,np.nan,inplace=True)
