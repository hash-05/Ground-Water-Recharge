# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('/content/DatasetGWR_Final.xlsx',sheet_name='Sheet2')

# %%
df
# Out:
#     District ID    District  Object Id  Longitude  Latitude     Slope  \
# 0             2  Hoshiarpur         52      74.75     31.25  0.784844
# 1             2  Hoshiarpur         53      75.00     31.25  0.701995
# 2             2  Hoshiarpur         60      74.75     31.50  0.000000
# 3             2  Hoshiarpur         61      75.00     31.50  1.889588
# 4             2  Hoshiarpur         62      75.25     31.50  0.351011
# ..          ...         ...        ...        ...       ...       ...
# 70           18     Patiala         19      75.75     30.25  2.353356
# 71           18     Patiala         20      76.00     30.25  1.889588
# 72           18     Patiala         29      75.50     30.50  0.351011
# 73           18     Patiala         30      75.75     30.50  1.265397
# 74           18     Patiala         31      76.00     30.50  1.109868
#
#            Soil Type         1986         1987         1988  ...    2010.3  \
# ...

# %%
l=list(df.columns)
pts=list(df['Object Id'].values)
d={}

# %%
years=[i for i in range(1986,2020)]

# %%
for i in pts:
  d[i]={'Longitude':df['Longitude'][pts.index(i)],'Latitude':df['Latitude'][pts.index(i)],
        'District ID':df['District ID'][pts.index(i)],'District':df['District'][pts.index(i)],'Slope':df['Slope'][pts.index(i)],
        'Soil Type':df['Soil Type'][pts.index(i)]}

# %%
d
# Out:
# {52: {'Longitude': 74.75,
#   'Latitude': 31.25,
#   'District ID': 2,
#   'District': 'Hoshiarpur',
#   'Slope': 0.784844,
#   'Soil Type': 'Haplic Calcisols'},
#  53: {'Longitude': 75.0,
#   'Latitude': 31.25,
#   'District ID': 2,
#   'District': 'Hoshiarpur',
#   'Slope': 0.701995,
#   'Soil Type': 'Haplic Calcisols'},
#  60: {'Longitude': 74.75,
#   'Latitude': 31.5,
#   'District ID': 2,
#   'District': 'Hoshiarpur',
#   'Slope': 0.0,
#   'Soil Type': 'Haplic Calcisols'},
#  61: {'Longitude': 75.0,
#   'Latitude': 31.5,
#   'District ID': 2,
#   'District': 'Hoshiarpur',
#   'Slope': 1.889588,
#   'Soil Type': 'Haplic Calcisols'},
#  62: {'Longitude': 75.25,
#   'Latitude': 31.5,
#   'District ID': 2,
#   'District': 'Hoshiarpur',
#   'Slope': 0.351011,
#   'Soil Type': 'Haplic Calcisols'},
#  66: {'Longitude': 74.75,
#   'Latitude': 31.75,
#   'District ID': 2,
#   'District': 'Hoshiarpur',
#   'Slope': 2.529561,
#   'Soil Type': 'Haplic Calcisols'},
# ...

# %%
df1=pd.DataFrame(columns=['Year','District ID','District','Longitude','Latitude','Slope','Soil Type','LULC','Temperature','Rainfall','Groundwater Recharge'])

# %%
for i in pts:
  df1=pd.DataFrame()
  v=list(df.iloc[pts.index(i),7:].values)
  df1['Year']=years
  df1['District ID']=d[i]['District ID']
  df1['District']=d[i]['District']
  df1['Longitude']=d[i]['Longitude']
  df1['Latitude']=d[i]['Latitude']
  df1['Slope']=d[i]['Slope']
  df1['Soil Type']=d[i]['Soil Type']
  df1['LULC']=v[0:34]
  df1['Temperature']=v[34:68]
  df1['Rainfall']=v[68:102]
  df1['Groundwater Recharge']=v[102:136]
  df1.to_excel(str(i)+'.xlsx',index=False)

# %%
from google.colab import files

for i in pts:
  files.download(str(i)+'.xlsx')

# %%
# Out:
#     Year  District ID    District  Longitude  Latitude     Slope  \
# 0   1986            2  Hoshiarpur      74.75     31.25  0.784844
# 1   1987            2  Hoshiarpur      74.75     31.25  0.784844
# 2   1988            2  Hoshiarpur      74.75     31.25  0.784844
# 3   1989            2  Hoshiarpur      74.75     31.25  0.784844
# 4   1990            2  Hoshiarpur      74.75     31.25  0.784844
# 5   1991            2  Hoshiarpur      74.75     31.25  0.784844
# 6   1992            2  Hoshiarpur      74.75     31.25  0.784844
# 7   1993            2  Hoshiarpur      74.75     31.25  0.784844
# 8   1994            2  Hoshiarpur      74.75     31.25  0.784844
# 9   1995            2  Hoshiarpur      74.75     31.25  0.784844
# 10  1996            2  Hoshiarpur      74.75     31.25  0.784844
# 11  1997            2  Hoshiarpur      74.75     31.25  0.784844
# 12  1998            2  Hoshiarpur      74.75     31.25  0.784844
# ...

# %%
df1['Year']=years
df1['District ID']=d[52]['District ID']
df1['District']=d[52]['District']
df1['Longitude']=d[52]['Longitude']
df1['Latitude']=d[52]['Latitude']
df1['Slope']=d[52]['Slope']
df1['Soil Type']=d[52]['Soil Type']
df1['LULC']=v[0][0:34]
df1['Temperature']=v[0][34:68]
df1['Rainfall']=v[0][68:102]
df1['Groundwater Recharge']=v[0][102:136]

# %%
v=list(df.iloc[0,7:].values)

# %%
v
# Out:
# ['Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Agriculture',
#  'Builtup',
#  'Builtup',
#  'Builtup',
#  'Builtup',
#  29.04750434989247,
#  30.7067751744086,
#  29.35088601817205,
#  29.1633515572043,
#  29.26033224161291,
#  36.04731823247312,
#  35.10439789612904,
#  29.57976881655914,
#  29.0658203988172,
#  29.75265159311828,
#  34.56825386301075,
#  34.11957630451612,
#  35.44932893354839,
#  29.61291722806451,
#  29.55172253860215,
#  29.61947631806452,
#  30.04564193924731,
#  29.38485262473119,
# ...

# %%
df1.tail()
# Out:
#     Year  District ID    District  Longitude  Latitude     Slope  \
# 29  2015            2  Hoshiarpur      74.75     31.25  0.784844
# 30  2016            2  Hoshiarpur      74.75     31.25  0.784844
# 31  2017            2  Hoshiarpur      74.75     31.25  0.784844
# 32  2018            2  Hoshiarpur      74.75     31.25  0.784844
# 33  2019            2  Hoshiarpur      74.75     31.25  0.784844
#
#            Soil Type         LULC Temperature   Rainfall Groundwater Recharge
# 29  Haplic Calcisols  Agriculture   29.406965  29.406965             -9.14336
# 30  Haplic Calcisols      Builtup   30.091457  30.091457            -9.823463
# 31  Haplic Calcisols      Builtup   29.834906  29.834906            -2.394697
# 32  Haplic Calcisols      Builtup    29.55036   29.55036            -2.774661
# 33  Haplic Calcisols      Builtup   30.028913  30.028913            -5.369132
